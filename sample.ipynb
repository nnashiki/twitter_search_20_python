# %%
# !pip install twitter
# Out:
# Collecting twitter
#   Downloading https://files.pythonhosted.org/packages/85/e2/f602e3f584503f03e0389491b251464f8ecfe2596ac86e6b9068fe7419d3/twitter-1.18.0-py2.py3-none-any.whl (54kB)
#      |████████████████████████████████| 61kB 1.9MB/s
# Installing collected packages: twitter
# Successfully installed twitter-1.18.0

# %%
from twitter import *

# %%
BEARER_TOKEN = ""
twitter = Twitter(auth=OAuth2(bearer_token=BEARER_TOKEN))

# Now work with Twitter
data = twitter.search.tweets(q='bigquery', count=100)

# %%
data['search_metadata']
# Out:
# {'completed_in': 0.096,
#  'count': 100,
#  'max_id': 1292001306622623745,
#  'max_id_str': '1292001306622623745',
#  'next_results': '?max_id=1291821852763942911&q=bigquery&count=100&include_entities=1',
#  'query': 'bigquery',
#  'refresh_url': '?since_id=1292001306622623745&q=bigquery&include_entities=1',
#  'since_id': 0,
#  'since_id_str': '0'}

# %%
for tweet_data in data['statuses']:
        if  'text' in tweet_data:
            print ("\n" * 5 + tweet_data['text'])
# Out:
# RT @na0fu3y: BigQueryと一緒にdbt使うと、依存順にクエリ実行してくれたり、スキーマのUNIQUEやNOT NULL、外部キー制約の他ENUMチェックまでやってくれる。 https://t.co/LB8JyLHZEv
#
#
#
#
#
# dbtをBigQueryで使ってみる｜ucwork #note https://t.co/gBMXz5Ce7x
#
#
#
#
#
# @_prestwich @EvgeMedvedev Actually, this is the relevant article. “How to Query Balances for all Ethereum Addresses… https://t.co/KWzRQY2sV2
#
#
#
#
#
# BigQueryと一緒にdbt使うと、依存順にクエリ実行してくれたり、スキーマのUNIQUEやNOT NULL、外部キー制約の他ENUMチェックまでやってくれる。 https://t.co/LB8JyLHZEv
#
#
#
#
#
# @_prestwich I know the past issuance. I did a full audit. And @EvgeMedvedev did, too (we worked together to get it… https://t.co/J5NuW8oZ1N
#
#
#
#
#
# RT @yasshi_dayooon: そういえばなんで僕SQLとBigQuery並列に言ったんだろ、、クラウドの勉強って言いたかったのかな、、、（記憶がない）
#
#
#
#
#
# RT @rhoboro: BigQueryに一度Aggregationして、そこをデータソースとしてデータ整形をすれば良いのかなって思った。
# 変換処理のインプットもアウトプットもBQになってると一元管理も処理の記述もやりやすいだろうなと。
# https://t.co/EC8hAh…
#
#
#
#
#
# BigQueryに一度Aggregationして、そこをデータソースとしてデータ整形をすれば良いのかなって思った。
# 変換処理のインプットもアウトプットもBQになってると一元管理も処理の記述もやりやすいだろうなと。
# https://t.co/EC8hAhJxA4
#
#
#
#
#
# そういえばなんで僕SQLとBigQuery並列に言ったんだろ、、クラウドの勉強って言いたかったのかな、、、（記憶がない） https://t.co/3WFKmyycXL
#
#
#
#
#
# @Informatica and @Google Cloud Expand Strategic Partnership to Accelerate Analytics with BigQuery and SAP on Google… https://t.co/DcwB7oWVmB
#
#
#
#
#
# データソースが色々ある場合、とりあえずBigQueryに集めて、きれいきれいするパターンが多いと思っていた。
# データソース側できれいきれいするのが望ましいが、管理しきれないイメージ。
#
# BigQueryに持ってくる前に、中間処理し… https://t.co/fFe7bsFuqZ
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# RT @na0fu3y: faker.jsを使ってBigQuery JavaScript UDFでダミーデータを作る記事。
#
# クエリのパフォーマンスチェックに。保存せずに無からデータを作ればBigQueryオンデマンド課金ではお金かからないのでお手軽。 https://t.co…
#
#
#
#
#
# faker.jsを使ってBigQuery JavaScript UDFでダミーデータを作る記事。
#
# クエリのパフォーマンスチェックに。保存せずに無からデータを作ればBigQueryオンデマンド課金ではお金かからないのでお手軽。 https://t.co/dpXMsl6OvZ
#
#
#
#
#
# RT @bunnyshellCloud: BigQuery Omni has the potential to open up the #cloud world to new types of unified macro-level meta-platform offering…
#
#
#
#
#
# RT @pvergadia: ✍️I tried to cover all the BigQuery goodness in this #GCPSketchnote including the newly announced features during #GoogleClo…
#
#
#
#
#
# @_prestwich Its perfectly ok, given its not trying to be sound money anyway.
# But better not to brag about a bigque… https://t.co/VAhY4sOJ6j
#
#
#
#
#
# SQLを変な独自な書式で書くのに多少の躊躇いもあったけど、なんとかなった。まあ最悪、SQLにロジック押し込めたviewをBigQuery側に作っちゃえばどうにでもなる
#
#
#
#
#
# RT @pvergadia: ✍️I tried to cover all the BigQuery goodness in this #GCPSketchnote including the newly announced features during #GoogleClo…
#
#
#
#
#
# Cloud RunにCube.jsのサーバー側を置いて、firebase hostingにクライアント側with React+rechartsで、無料のData Studioと戦えるコスト感。DBは引き続きBigQueryなのでそこまで自分で管理してる感もないし
#
#
#
#
#
# RT @rseroter: "Here’s a quick tutorial on using a Javascript UDF with the faker.js library to generate billions of lines of fake data, in m…
#
#
#
#
#
# RT @rseroter: "Here’s a quick tutorial on using a Javascript UDF with the faker.js library to generate billions of lines of fake data, in m…
#
#
#
#
#
# Cube.js なかなかよくできてて特にサーバーとクライアントに分離してるのが使いやすい。BigQueryにも標準で対応してるのもよい
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# @willnorris Thanks @willnorris, glad to see this data. Was inspired to check out GHArchive and stumbled across this… https://t.co/5zIiJ3TUbe
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# Introducing the #Google #Analytics Sample #Dataset for #BigQuery https://t.co/pxJmEiYwIk)
#
#
#
#
#
# RT @thomasvlatum: I'm happy to finally share a blogpost about running TensorFlow models on #BigQuery! I wrote this blogpost together with m…
#
#
#
#
#
# BigQuery使いこなしたいな、、
# 分析できるとこめっちゃ増える。
#
# 広告運用と顧客データってほんと
# マーケター悩みあるある。
# データポータルで一部自動化できたし
# 基盤データとの連携ももっとやっていきたい！
# #マーケター　#データ https://t.co/pAiJvpeHQj
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# RT @pvergadia: ✍️I tried to cover all the BigQuery goodness in this #GCPSketchnote including the newly announced features during #GoogleClo…
#
#
#
#
#
# @kylebarron2 @ApacheArrow And then ideally BigQuery or @SnowflakeDB would also be able to read in the same core for… https://t.co/DpiSOI9Sti
#
#
#
#
#
# ああPrep2020.3のマイナーアップデートでBigQuery書き込みでてよ、頼むよ！（それに向けて頑張ってる感はある）
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# RT @maxbill_design: How to have full control of #BigQuery CRUD in your #Angular #application - #tutorial &gt; https://t.co/g0Vc94O4lm | #javas…
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# RT @maxbill_design: How to have full control of #BigQuery CRUD in your #Angular #application - #tutorial &gt; https://t.co/g0Vc94O4lm | #javas…
#
#
#
#
#
# RT @maxbill_design: How to have full control of #BigQuery CRUD in your #Angular #application - #tutorial &gt; https://t.co/g0Vc94O4lm | #javas…
#
#
#
#
#
# 弊社の新作 note です。#BigQuery を使ってみたい方、また使う前にどのように活用するか理解したい方。是非読んでみてくださいね😃✨
# https://t.co/9O9G093zkP
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# RT @pvergadia: ✍️I tried to cover all the BigQuery goodness in this #GCPSketchnote including the newly announced features during #GoogleClo…
#
#
#
#
#
# RT @pvergadia: ✍️I tried to cover all the BigQuery goodness in this #GCPSketchnote including the newly announced features during #GoogleClo…
#
#
#
#
#
# @DOtykier @BNeelon I had a project where i started with PQ,  it was a total failure,  end up using Python cloud fun… https://t.co/NV1tO0pzC7
#
#
#
#
#
# When migrating a data warehouse to BigQuery, it's key to map existing user permissions to equivalent Google Cloud I… https://t.co/cvUD4tIS3T
#
#
#
#
#
# RT @GCPcloud: Data QnA, a natural language interface for analytics on #BigQuery data, is now in private alpha. Here's how it enables busine…
#
#
#
#
#
# #BigQueryOmni is our new multi-cloud analytics solution, powered by Anthos. Now you can access and analyze data acr… https://t.co/cYzQJ8ErJo
#
#
#
#
#
# Interesting read. @ProcterGamble is migrating consumer data from an on-premise solution to Google's cloud platform,… https://t.co/HtdIItqbMt
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# KeyBank saw 3 to 4x faster query performance after migrating from their Teradata data warehouse to @GoogleCloud. Le… https://t.co/TBMGFSDX03
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# @EriShirai BigQueryは未経験のでやってみます
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# RT @rvg296: Just finished this big query podcast from @cwj02 . It's fascinating to learn the #BigQueryGIS use cases and how Geospatial data…
#
#
#
#
#
# Just finished this big query podcast from @cwj02 . It's fascinating to learn the #BigQueryGIS use cases and how Geo… https://t.co/fNIgY8wQ2r
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# 🔥 @MattiasEh is bringing us all the latest news from GCP this month!
# &gt; Major announcements from Google OnAir '20
# &gt;… https://t.co/94YHdrYZcV
#
#
#
#
#
# RT @AiThority: @ClearBlade Releases BigQuery Edge Data Streaming Feature In Partnership With Google Cloud https://t.co/2XkHrfxZoa #blockcha…
#
#
#
#
#
# RT @AiThority: @ClearBlade Releases BigQuery Edge Data Streaming Feature In Partnership With Google Cloud https://t.co/2XkHrfxZoa #blockcha…
#
#
#
#
#
# RT @senutocryon: @lopp @pierre_rochard @josephjpeters @bitstein @dustin_dettmer @ercwl Wait, for those of us who don't know what bigquery i…
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# RT @rseroter: "Here’s a quick tutorial on using a Javascript UDF with the faker.js library to generate billions of lines of fake data, in m…
#
#
#
#
#
# RT @rseroter: "Here’s a quick tutorial on using a Javascript UDF with the faker.js library to generate billions of lines of fake data, in m…
#
#
#
#
#
# "Here’s a quick tutorial on using a Javascript UDF with the faker.js library to generate billions of lines of fake… https://t.co/3OqUWlNYQ9
#
#
#
#
#
# RT @ykfermi: こ れ は  ま じ で そ う
#
# BigQueryとExcelと統計、特にBigQueryは最強 https://t.co/saDuzL7ypS
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# RT @_datahack: Fecha: DataLive 26 de agosto.
#
# #AWS #Azure #GoogleCloud #GCP #Cloud #AI #ML #Kubernetes #BigQuery #ArtificialIntelligence #M…
#
#
#
#
#
# RT @_datahack: Fecha: DataLive 26 de agosto.
#
# #AWS #Azure #GoogleCloud #GCP #Cloud #AI #ML #Kubernetes #BigQuery #ArtificialIntelligence #M…
#
#
#
#
#
# Fecha: DataLive 26 de agosto.
#
# #AWS #Azure #GoogleCloud #GCP #Cloud #AI #ML #Kubernetes #BigQuery… https://t.co/aaYL4dGyzK
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# Google BigQuery and PostgreSQL: SQL for Data Analysis
#
# Length: 10.5 hours
# Rating: 4.12
# Students: 19187
# Last updat… https://t.co/fQVD0fQO1E
#
#
#
#
#
# @woloski @tjholowaychuk @ApexLogs Probably just BigQuery which is used to do all the hard work.
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# RT @maxbill_design: How to have full control of #BigQuery CRUD in your #Angular #application - #tutorial &gt; https://t.co/g0Vc94O4lm | #javas…
#
#
#
#
#
# RT @maxbill_design: How to have full control of #BigQuery CRUD in your #Angular #application - #tutorial &gt; https://t.co/g0Vc94O4lm | #javas…
#
#
#
#
#
# RT @maxbill_design: How to have full control of #BigQuery CRUD in your #Angular #application - #tutorial &gt; https://t.co/g0Vc94O4lm | #javas…
#
#
#
#
#
# How to have full control of #BigQuery CRUD in your #Angular #application - #tutorial &gt; https://t.co/g0Vc94O4lm |… https://t.co/V2BwmtMnJX
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# @ClearBlade Releases BigQuery Edge Data Streaming Feature In Partnership With Google Cloud https://t.co/2XkHrfxZoa… https://t.co/sR0YakE7eW
#
#
#
#
#
# @GreeneScientist @alexisjbattle I do use bigquery quite a bit and Postgres servers to host data on GCP
#
#
#
#
#
# @techceopepe I was interviewed for a role where the dudes were happily paying out a variable cost between $5k and $… https://t.co/BYCJGRTRfS
#
#
#
#
#
# RT @EriShirai: データアナリストになりたい人はPythonとか言語から学んでいる人も多いと思いますが、GCPのBigQueryやSQLやExcelをまずやった方がいいです。ただ統計学は学んだ方がいいです。あと提案書の形で伝える技術もあったほうがいいし、色んな人と話…
#
#
#
#
#
# RT @thomasvlatum: I'm happy to finally share a blogpost about running TensorFlow models on #BigQuery! I wrote this blogpost together with m…
#
#
#
#
#
# BigQueryってなんだっけ? そんな君たちに教えたい本見つけたのでまとめてみる。 https://t.co/ca4gD2O363
#
#
#
#
#
# • Advanced SQL knowledge, database and data modeling knowledge are a must.
# • Strong business acumen, understanding… https://t.co/QQj7HTdv20
#
#
#
#
#
# #GoogleCloud Yet another way to generate fake datasets in BigQuery https://t.co/44u1paU08z
#
#
#
#
#
# RT @baborin: Google BigQueryとGoogleデータポータル(Data Studio)を使い始めてCOVID-19感染者数のグラフを作るまで https://t.co/4UrQ05pcgO
